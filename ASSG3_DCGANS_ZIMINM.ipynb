# %% [markdown]
# #CITS4404 - ASSIGNMENT 3
#
# ## Zimin Meng 22665473

# %%
##omit this if using other tools
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import torch
from torchvision import datasets
from torchvision import transforms
import scipy.io as sio

# %matplotlib inline

# %%
from scipy.io import loadmat


#compare the shape of image set
#print(extra.shape): (32, 32, 3, 50)
#print(train['X'].shape) : (32, 32, 3, 73257)

# Tensor transform, will use to transform data to Tensor datatype
transform = transforms.ToTensor()

svhn_train = datasets.SVHN(root='data/', split='train', download= True, transform=transform)
#Alternative: train = loadmat('data/train_32x32.mat')
#train_s = svhn_train['X']
# Out:
# Downloading http://ufldl.stanford.edu/housenumbers/train_32x32.mat to data/train_32x32.mat
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
#load extra image set which contains 50 new images and have been transformed
extra = sio.loadmat('/extra.mat')
#extra = sio.loadmat('/content/drive/My Drive/extra.mat')
extra_s = extra['A']

# shape of extra_s i (32, 32, 3, 50), in HWCN format but numpy array in svhn_train is NCHW so we need to transpose it
# shape of extra data after this operation become after transpose(50, 3, 32, 32) 
extra_data_np = extra_s.transpose(3, 2, 0, 1)

#append extra data set and training data set
training_np = np.concatenate((extra_data_np, svhn_train.data), axis = 0)
# training_np.shape check the shape:(73307, 3, 32, 32)

# %%
#Visualize some extra images

def show_extra_images():
    # randomly generate 10 sample image from 
    idx = np.random.randint(0, extra_s.shape[3], size=10)
    fig, axes = plt.subplots(1, 10, sharex=True, sharey=True, figsize=(20, 4), )
    for ii, ax in zip(idx, axes.flatten()):
        ax.imshow(extra_s[:, :, :, ii], aspect='equal')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()
show_extra_images()

# %%
# convert numpy data to torch data
training_ts = torch.Tensor(training_np)
# convert tensor data to a dataset can be used for dataloader
train = torch.utils.data.TensorDataset(training_ts)

batch_size = 128
num_workers = 0

# create DataLoaders for SVHN dataset - help batch data into batches of specific size
train_loader = torch.utils.data.DataLoader(dataset=train,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=num_workers)

# %%
# take one batch of training images
#remove labels, due to extra images don't have labels
dataiter = iter(train_loader)
images= dataiter.next()
print(type(images))
print(type(images[0]))
# Out:
# <class 'list'>
# <class 'torch.Tensor'>

# %%
#Plot the images
fig = plt.figure(figsize=(25, 4))
plot_size=20
for idxx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idxx+1, xticks=[], yticks=[])
    pics = images[0]
    ax.imshow(np.transpose(pics[idxx], (1, 2, 0))/255)

# %%
## current range
img = images[0]

print('Min: ', img.min())
print('Max: ', img.max())
# Out:
# Min:  tensor(0.)
# Max:  tensor(255.)

# %%
# The output of our G will be tanh activated e.i. on a range from [-1 1], 
# We need to rescale training images to that range. (Currently: [0 1])
def scale(xx, feature_range=(-1, 1)):
    ''' INPUT: image xx scaled to [0 255]
       OUTPUT: image scaled [-1 1] '''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    xx = xx/255
    xx = xx * (max - min) + min
    return xx

# %%
# scale image
scaled_img = scale(img)

print('Scaled min: ', scaled_img.min())
print('Scaled max: ', scaled_img.max())
# Out:
# Scaled min:  tensor(-1.)
# Scaled max:  tensor(1.)

# %% [markdown]
# Home numbers dataset is more complex than MNIST, we will train a deeper network to identify patterns in these images and generate new ones.
# Use a series of convolutional and transpose convolutional layers in the discriminator and generator respectively.
# Use batch normalization to get convolutional networks to train faster/beter.

# %%
import torch.nn as nn
import torch.nn.functional as F

def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    # bias is set to False, so the layers are not offset by any amount
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
# Use batch normalization with nn.BatchNorm2d on each layer except 
# the 1st convolutional layer and final linear output layer.
# In the DCGAN paper, they did all the downsampling using only strided convolutional layers with no maxpooling layers

class Discriminator(nn.Module):
    def __init__(self, conv_dim=32):
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        # 32x32 input, 16x16 output
        self.conv1 = conv(3, conv_dim, 4, batch_norm= False) # 1st layer, no batch_norm 
        self.conv2 = conv(conv_dim, conv_dim*2, 4)   # 8x8 output
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4) # 4x4 output
        
        # final fully-connected layer - produces 1 output (par 2)
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, xx):
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(xx),  0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        out = self.fc(out)        
        return out

# %%
# define a function that will allow us to do:
# transpose convolution -> batch norm (optional: T/F) -> ReLU
# Use kernel_size 4 & stride 2 for transpose convolutions

def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Create a transposed-convolutional layer with optional batch normalization """
    # create a sequence of transpose + optional batch norm layers
    layers = [] # empty list of layers
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
# In G 1st layer is a fully connected layer which is reshaped into a deep and narrow layer, eg. 4x4x512
# Then use batch norm & leaky ReLU activation
# Next is a series of transpose convolutional layers where you typically have the depth and double the width and height of the previous layer
# Apply batch normalization and ReLU to all but the last hidden layer. Where we apply a tanh activation

# Input: randomly generated vector z
# Output tanh values of size 32x32 which is the size of the SVHN images

class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # first fully-connected layer, 
        # params: latent verctor z & produces a layer 4x4x128
        #         4x4 part defined in the forward step below
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers, kernel_size = 4,
        # desired depth for RGB image is 3
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, xx):
        # fully-connected + reshape 
        out = self.fc(xx)
        # params: batch_size, depth, 4, 4
        # -1 is a place holder for batch size
        # 128 - depth as defined by the convolutional dimention
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))
        
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)
        
        return out

# %%
# define hyperparams
conv_dim = 32
z_size = 100

# instantiate D and G
D = Discriminator(conv_dim)
G = Generator(z_size=z_size, conv_dim=conv_dim)

print(D)
print()
print(G)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU...')
# Out:
# GPU available for training. Models moved to GPU

# %%
# Define Losses
# For D the total loss is the sum of the losses for real and fake images:
#     d_loss = d_real_loss + d_fake_loss
# The losses will by binary cross entropy loss with logits (BCEWithLogitsLoss). 
# BCEWithLogitsLoss combines a sigmoid activation function and a binary cross entropy loss
# We want D to output 1 for real images and 0 for fake images, make sure the losses to reflect that.
#
# For real images we want D(real_images) = 1, i.e. classify real images as = 1. 
# D's loss for the fake data is D(fake_images) = 0, where fake images are G's output, fake_images = G(z).
#
# For G the loss is similar but with labels flipped. G's goal is to get D(fake_images) = 1. 
# In this case, the labels are flipped to represent that the generator is trying to fool the discriminator 
# into thinking that the fake images it generates are real


def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
# Optimisers, similar to what we did before

import torch.optim as optim

# params suggested to be good in the DCGAN paper 
# GANs can be very seinsitive to small changes in parameter values
# Check out some options in the DCGAN paper:
#    https://arxiv.org/pdf/1511.06434.pdf

#learning rate initially set as lr and then varies as epoch increases
lr = 0.01
beta1=0.5
beta2=0.999 # default value


# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

    
def adjust_learning_rate(d_optimizer, g_optimizer, new_lr):
    for d_param in d_optimizer.param_groups:
      d_param['lr'] = new_lr
    for g_param in g_optimizer.param_groups:
     g_param['lr'] = new_lr

# %%
d_optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: [0.5, 0.999]
#     eps: 1e-08
#     lr: 0.005
#     weight_decay: 0
# )

# %%
# Discriminator training
#   Compute the discriminator loss on real, training images
#   Generate fake images
#   Compute the discriminator loss on fake, generated images
#   Add up real and fake loss
#   Perform backpropagation + an optimization step to update the discriminator's weights
#
# Generator training
#   Generate fake images
#   Compute the discriminator loss on fake images, using flipped labels!
#   Perform backpropagation + an optimization step to update the generator's weights


import pickle as pkl # to save intermediate fake images

# training hyperparams
num_epochs = 100 # will run for a 2-4 hours

# keep track of loss and fake samples
samples = []
losses = []
print_every = 100

# Get some fixed data for evaluating the model's performance as we train
# Keep these images constant
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
for epoch in range(num_epochs):
    lr = 0.01
    if epoch > 20:
        lr = 0.005
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 40:
        lr = 0.002
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 60:
        lr = 0.001
        adjust_learning_rate(d_optimizer, g_optimizer, lr)
    if epoch > 80:
        lr = 0.0005
        adjust_learning_rate(d_optimizer, g_optimizer, lr)


    for batch_i, real_images in enumerate(train_loader):
        real_images = real_images[0]        
        batch_size = real_images.size(0)
        
        # important rescaling step
        real_images = scale(real_images)
        
        # train D
        d_optimizer.zero_grad()
        
        # 1. Train with real images
        # Compute the D losses on real images 
        if train_on_gpu:
            real_images = real_images.cuda()
        
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)
        
        # 2. Train with fake images
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        # move to GPU, if available
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images            
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # train G
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels 
        # Generate fake images
        zz = np.random.uniform(-1, 1, size=(batch_size, z_size))
        zz = torch.from_numpy(zz).float()
        if train_on_gpu:
            zz = zz.cuda()
        fake_images = G(zz)
        
        # Compute the D losses on fake images 
        # using flipped labels
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()

        # Print some loss stats
        if batch_i % print_every == 0:
            # append D loss and G loss
            losses.append((d_loss.item(), g_loss.item()))
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    # AFTER EACH EPOCH    
    # generate and save fake images
    G.eval() # eval mode for generating samples
    # eval mode - batch_norm & drop out behave differently in generating new samples
    # batch_norm should use population statistics instead of batch statistics in eval
    # dropout should not drop any nodes during testing
    
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # switch back to training mode

# Save training generator samples
with open('fake_images.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 0.0025 | g_loss: 7.8932
# Epoch [    1/  100] | d_loss: 0.0349 | g_loss: 7.8537
# Epoch [    1/  100] | d_loss: 0.0019 | g_loss: 7.5326
# Epoch [    1/  100] | d_loss: 0.0092 | g_loss: 8.8983
# Epoch [    1/  100] | d_loss: 0.0042 | g_loss: 9.1156
# Epoch [    1/  100] | d_loss: 0.0017 | g_loss: 9.0293
# Epoch [    2/  100] | d_loss: 0.0165 | g_loss: 7.7022
# Epoch [    2/  100] | d_loss: 0.0058 | g_loss: 8.8298
# Epoch [    2/  100] | d_loss: 0.0010 | g_loss: 7.0510
# Epoch [    2/  100] | d_loss: 0.0043 | g_loss: 8.5826
# Epoch [    2/  100] | d_loss: 0.0013 | g_loss: 9.2366
# Epoch [    2/  100] | d_loss: 0.0040 | g_loss: 7.5412
# Epoch [    3/  100] | d_loss: 0.0037 | g_loss: 8.5716
# Epoch [    3/  100] | d_loss: 0.0069 | g_loss: 9.1984
# Epoch [    3/  100] | d_loss: 0.0070 | g_loss: 9.2510
# Epoch [    3/  100] | d_loss: 0.0047 | g_loss: 8.9046
# Epoch [    3/  100] | d_loss: 0.0030 | g_loss: 6.3069
# Epoch [    3/  100] | d_loss: 0.0014 | g_loss: 7.7199
# Epoch [    4/  100] | d_loss: 0.0022 | g_loss: 7.8544
# Epoch [    4/  100] | d_loss: 0.0089 | g_loss: 7.9883
# Epoch [    4/  100] | d_loss: 0.0298 | g_loss: 9.1580
# Epoch [    4/  100] | d_loss: 0.0032 | g_loss: 10.9416
# Epoch [    4/  100] | d_loss: 0.0030 | g_loss: 9.1010
# Epoch [    4/  100] | d_loss: 0.0059 | g_loss: 7.9836
# Epoch [    5/  100] | d_loss: 0.0029 | g_loss: 9.2334
# Epoch [    5/  100] | d_loss: 0.0075 | g_loss: 6.9363
# Epoch [    5/  100] | d_loss: 0.0083 | g_loss: 8.3363
# Epoch [    5/  100] | d_loss: 0.0118 | g_loss: 7.3924
# Epoch [    5/  100] | d_loss: 0.0144 | g_loss: 8.2374
# Epoch [    5/  100] | d_loss: 0.0460 | g_loss: 7.9159
# Epoch [    6/  100] | d_loss: 0.0051 | g_loss: 8.6599
# Epoch [    6/  100] | d_loss: 0.0167 | g_loss: 7.0087
# Epoch [    6/  100] | d_loss: 0.0104 | g_loss: 9.2667
# Epoch [    6/  100] | d_loss: 0.0016 | g_loss: 8.9751
# Epoch [    6/  100] | d_loss: 0.0013 | g_loss: 8.4560
# Epoch [    6/  100] | d_loss: 0.0113 | g_loss: 8.0909
# Epoch [    7/  100] | d_loss: 0.0013 | g_loss: 7.6541
# Epoch [    7/  100] | d_loss: 0.0055 | g_loss: 8.8301
# Epoch [    7/  100] | d_loss: 0.0051 | g_loss: 8.4121
# Epoch [    7/  100] | d_loss: 0.0115 | g_loss: 7.6321
# Epoch [    7/  100] | d_loss: 0.0047 | g_loss: 8.7045
# Epoch [    7/  100] | d_loss: 0.0055 | g_loss: 8.1103
# Epoch [    8/  100] | d_loss: 0.0049 | g_loss: 9.2959
# Epoch [    8/  100] | d_loss: 0.0130 | g_loss: 8.5098
# Epoch [    8/  100] | d_loss: 0.0124 | g_loss: 8.3302
# Epoch [    8/  100] | d_loss: 0.0171 | g_loss: 9.5892
# Epoch [    8/  100] | d_loss: 0.0065 | g_loss: 7.3203
# Epoch [    8/  100] | d_loss: 0.0062 | g_loss: 10.0007
# Epoch [    9/  100] | d_loss: 0.0341 | g_loss: 8.3937
# Epoch [    9/  100] | d_loss: 0.0011 | g_loss: 9.6385
# Epoch [    9/  100] | d_loss: 0.0007 | g_loss: 7.0921
# Epoch [    9/  100] | d_loss: 0.0106 | g_loss: 8.2593
# Epoch [    9/  100] | d_loss: 0.0027 | g_loss: 8.0310
# Epoch [    9/  100] | d_loss: 0.0289 | g_loss: 7.7570
# Epoch [   10/  100] | d_loss: 0.0064 | g_loss: 9.3715
# Epoch [   10/  100] | d_loss: 0.0096 | g_loss: 8.9681
# Epoch [   10/  100] | d_loss: 0.0025 | g_loss: 10.8074
# Epoch [   10/  100] | d_loss: 0.0037 | g_loss: 8.1120
# Epoch [   10/  100] | d_loss: 0.0077 | g_loss: 7.5312
# Epoch [   10/  100] | d_loss: 0.0282 | g_loss: 5.9405
# Epoch [   11/  100] | d_loss: 0.0029 | g_loss: 7.4422
# Epoch [   11/  100] | d_loss: 0.0027 | g_loss: 7.8679
# Epoch [   11/  100] | d_loss: 0.0095 | g_loss: 9.9921
# Epoch [   11/  100] | d_loss: 0.0459 | g_loss: 7.7489
# Epoch [   11/  100] | d_loss: 0.0157 | g_loss: 6.9338
# Epoch [   11/  100] | d_loss: 0.0044 | g_loss: 9.2097
# Epoch [   12/  100] | d_loss: 0.0027 | g_loss: 9.7556
# Epoch [   12/  100] | d_loss: 0.0067 | g_loss: 9.9220
# Epoch [   12/  100] | d_loss: 0.0299 | g_loss: 7.5550
# Epoch [   12/  100] | d_loss: 0.0246 | g_loss: 9.4322
# Epoch [   12/  100] | d_loss: 0.0026 | g_loss: 10.7114
# Epoch [   12/  100] | d_loss: 0.0115 | g_loss: 9.4113
# Epoch [   13/  100] | d_loss: 0.0109 | g_loss: 7.0340
# Epoch [   13/  100] | d_loss: 0.0049 | g_loss: 8.4059
# Epoch [   13/  100] | d_loss: 0.0326 | g_loss: 9.5627
# Epoch [   13/  100] | d_loss: 0.0046 | g_loss: 7.9444
# Epoch [   13/  100] | d_loss: 0.0130 | g_loss: 7.8611
# Epoch [   13/  100] | d_loss: 0.0013 | g_loss: 9.9524
# Epoch [   14/  100] | d_loss: 0.0369 | g_loss: 9.9711
# Epoch [   14/  100] | d_loss: 0.0012 | g_loss: 8.8063
# Epoch [   14/  100] | d_loss: 0.0477 | g_loss: 6.3100
# Epoch [   14/  100] | d_loss: 0.0130 | g_loss: 7.3839
# Epoch [   14/  100] | d_loss: 0.0133 | g_loss: 7.8467
# Epoch [   14/  100] | d_loss: 0.0184 | g_loss: 7.0051
# Epoch [   15/  100] | d_loss: 0.0102 | g_loss: 8.5356
# Epoch [   15/  100] | d_loss: 0.0075 | g_loss: 7.1698
# Epoch [   15/  100] | d_loss: 0.0017 | g_loss: 8.5497
# Epoch [   15/  100] | d_loss: 0.0139 | g_loss: 8.8172
# Epoch [   15/  100] | d_loss: 0.0045 | g_loss: 9.4189
# Epoch [   15/  100] | d_loss: 0.0066 | g_loss: 8.9002
# Epoch [   16/  100] | d_loss: 0.0018 | g_loss: 8.0813
# Epoch [   16/  100] | d_loss: 0.0018 | g_loss: 8.2579
# Epoch [   16/  100] | d_loss: 0.0219 | g_loss: 8.1986
# Epoch [   16/  100] | d_loss: 0.0042 | g_loss: 8.3171
# Epoch [   16/  100] | d_loss: 0.0295 | g_loss: 8.0663
# Epoch [   16/  100] | d_loss: 0.0140 | g_loss: 7.1641
# Epoch [   17/  100] | d_loss: 0.0146 | g_loss: 6.1730
# Epoch [   17/  100] | d_loss: 0.0080 | g_loss: 9.7256
# Epoch [   17/  100] | d_loss: 0.0032 | g_loss: 7.6397
# Epoch [   17/  100] | d_loss: 0.0033 | g_loss: 10.4077
# Epoch [   17/  100] | d_loss: 0.0063 | g_loss: 9.8661
# Epoch [   17/  100] | d_loss: 0.0050 | g_loss: 8.3785
# Epoch [   18/  100] | d_loss: 0.0436 | g_loss: 9.7048
# Epoch [   18/  100] | d_loss: 0.0424 | g_loss: 8.2562
# Epoch [   18/  100] | d_loss: 0.0082 | g_loss: 7.1643
# Epoch [   18/  100] | d_loss: 0.0016 | g_loss: 8.6735
# Epoch [   18/  100] | d_loss: 0.0110 | g_loss: 9.4524
# Epoch [   18/  100] | d_loss: 0.0011 | g_loss: 10.2969
# Epoch [   19/  100] | d_loss: 0.0086 | g_loss: 6.8206
# Epoch [   19/  100] | d_loss: 0.0197 | g_loss: 6.9391
# Epoch [   19/  100] | d_loss: 0.0028 | g_loss: 6.4485
# Epoch [   19/  100] | d_loss: 0.0027 | g_loss: 8.6729
# Epoch [   19/  100] | d_loss: 0.0017 | g_loss: 8.2445
# Epoch [   19/  100] | d_loss: 0.0087 | g_loss: 7.3117
# Epoch [   20/  100] | d_loss: 0.0130 | g_loss: 8.7055
# Epoch [   20/  100] | d_loss: 0.0034 | g_loss: 9.4447
# Epoch [   20/  100] | d_loss: 0.0034 | g_loss: 7.8633
# Epoch [   20/  100] | d_loss: 0.0129 | g_loss: 8.7223
# Epoch [   20/  100] | d_loss: 0.0047 | g_loss: 9.4236
# Epoch [   20/  100] | d_loss: 0.0052 | g_loss: 7.6844
# Epoch [   21/  100] | d_loss: 0.0397 | g_loss: 8.7805
# Epoch [   21/  100] | d_loss: 0.0126 | g_loss: 8.2389
# Epoch [   21/  100] | d_loss: 0.0074 | g_loss: 7.0293
# Epoch [   21/  100] | d_loss: 0.0132 | g_loss: 9.3317
# Epoch [   21/  100] | d_loss: 0.0141 | g_loss: 6.8395
# Epoch [   21/  100] | d_loss: 0.0117 | g_loss: 7.3091
# Epoch [   22/  100] | d_loss: 0.0330 | g_loss: 3.1462
# Epoch [   22/  100] | d_loss: 1.6434 | g_loss: 1.1893
# Epoch [   22/  100] | d_loss: 1.6637 | g_loss: 1.1549
# Epoch [   22/  100] | d_loss: 1.4563 | g_loss: 0.7883
# Epoch [   22/  100] | d_loss: 1.2423 | g_loss: 0.8696
# Epoch [   22/  100] | d_loss: 1.4521 | g_loss: 1.1683
# Epoch [   23/  100] | d_loss: 1.3497 | g_loss: 0.8245
# Epoch [   23/  100] | d_loss: 1.4031 | g_loss: 0.8350
# Epoch [   23/  100] | d_loss: 1.4021 | g_loss: 0.8703
# Epoch [   23/  100] | d_loss: 1.3192 | g_loss: 1.1411
# Epoch [   23/  100] | d_loss: 1.0675 | g_loss: 1.1107
# Epoch [   23/  100] | d_loss: 1.1894 | g_loss: 1.2045
# Epoch [   24/  100] | d_loss: 1.1362 | g_loss: 1.6787
# Epoch [   24/  100] | d_loss: 1.1671 | g_loss: 1.8451
# Epoch [   24/  100] | d_loss: 1.1879 | g_loss: 1.1039
# Epoch [   24/  100] | d_loss: 0.9338 | g_loss: 4.9273
# Epoch [   24/  100] | d_loss: 0.2934 | g_loss: 4.8381
# Epoch [   24/  100] | d_loss: 0.7557 | g_loss: 7.4976
# Epoch [   25/  100] | d_loss: 0.7172 | g_loss: 4.3220
# Epoch [   25/  100] | d_loss: 0.6302 | g_loss: 5.2521
# Epoch [   25/  100] | d_loss: 0.0709 | g_loss: 8.1304
# Epoch [   25/  100] | d_loss: 0.0499 | g_loss: 5.8837
# Epoch [   25/  100] | d_loss: 0.0182 | g_loss: 5.6167
# Epoch [   25/  100] | d_loss: 0.5952 | g_loss: 7.6710
# Epoch [   26/  100] | d_loss: 0.0249 | g_loss: 6.5158
# Epoch [   26/  100] | d_loss: 0.1035 | g_loss: 5.5580
# Epoch [   26/  100] | d_loss: 0.0341 | g_loss: 7.0378
# Epoch [   26/  100] | d_loss: 0.0314 | g_loss: 5.3439
# Epoch [   26/  100] | d_loss: 0.0230 | g_loss: 4.3754
# Epoch [   26/  100] | d_loss: 0.0650 | g_loss: 6.4607
# Epoch [   27/  100] | d_loss: 0.1086 | g_loss: 6.9426
# Epoch [   27/  100] | d_loss: 0.1123 | g_loss: 6.4896
# Epoch [   27/  100] | d_loss: 0.0698 | g_loss: 5.8354
# Epoch [   27/  100] | d_loss: 0.0087 | g_loss: 6.8829
# Epoch [   27/  100] | d_loss: 0.2272 | g_loss: 4.7533
# Epoch [   27/  100] | d_loss: 1.1785 | g_loss: 1.3350
# Epoch [   28/  100] | d_loss: 0.0371 | g_loss: 6.1417
# Epoch [   28/  100] | d_loss: 0.1232 | g_loss: 5.5153
# Epoch [   28/  100] | d_loss: 0.1025 | g_loss: 8.6627
# Epoch [   28/  100] | d_loss: 0.0398 | g_loss: 6.0184
# Epoch [   28/  100] | d_loss: 0.0338 | g_loss: 6.4082
# Epoch [   28/  100] | d_loss: 0.0218 | g_loss: 4.2531
# Epoch [   29/  100] | d_loss: 0.0538 | g_loss: 5.6700
# Epoch [   29/  100] | d_loss: 0.0348 | g_loss: 6.0693
# Epoch [   29/  100] | d_loss: 8.7400 | g_loss: 0.0228
# Epoch [   29/  100] | d_loss: 0.1182 | g_loss: 5.7051
# Epoch [   29/  100] | d_loss: 0.0340 | g_loss: 8.0993
# Epoch [   29/  100] | d_loss: 0.0250 | g_loss: 8.9262
# Epoch [   30/  100] | d_loss: 0.0277 | g_loss: 8.6741
# Epoch [   30/  100] | d_loss: 0.0767 | g_loss: 5.9668
# Epoch [   30/  100] | d_loss: 0.0231 | g_loss: 4.4379
# Epoch [   30/  100] | d_loss: 0.0473 | g_loss: 6.9360
# Epoch [   30/  100] | d_loss: 0.0254 | g_loss: 7.4722
# Epoch [   30/  100] | d_loss: 0.0100 | g_loss: 8.4109
# Epoch [   31/  100] | d_loss: 0.0569 | g_loss: 7.2009
# Epoch [   31/  100] | d_loss: 0.1676 | g_loss: 7.2901
# Epoch [   31/  100] | d_loss: 0.0041 | g_loss: 7.3106
# Epoch [   31/  100] | d_loss: 0.0468 | g_loss: 6.9552
# Epoch [   31/  100] | d_loss: 0.0257 | g_loss: 8.9643
# Epoch [   31/  100] | d_loss: 0.0547 | g_loss: 6.2685
# Epoch [   32/  100] | d_loss: 0.0777 | g_loss: 9.8820
# Epoch [   32/  100] | d_loss: 0.0261 | g_loss: 5.2322
# Epoch [   32/  100] | d_loss: 0.0054 | g_loss: 10.3209
# Epoch [   32/  100] | d_loss: 0.0133 | g_loss: 6.9405
# Epoch [   32/  100] | d_loss: 0.0089 | g_loss: 7.4952
# Epoch [   32/  100] | d_loss: 0.1486 | g_loss: 4.8570
# Epoch [   33/  100] | d_loss: 0.0286 | g_loss: 5.4140
# Epoch [   33/  100] | d_loss: 0.0327 | g_loss: 6.4694
# Epoch [   33/  100] | d_loss: 0.0162 | g_loss: 9.4131
# Epoch [   33/  100] | d_loss: 0.0232 | g_loss: 8.9870
# Epoch [   33/  100] | d_loss: 0.0650 | g_loss: 4.1386
# Epoch [   33/  100] | d_loss: 0.0126 | g_loss: 6.5468
# Epoch [   34/  100] | d_loss: 0.0298 | g_loss: 8.7426
# Epoch [   34/  100] | d_loss: 0.0129 | g_loss: 5.9405
# Epoch [   34/  100] | d_loss: 0.0980 | g_loss: 7.3988
# Epoch [   34/  100] | d_loss: 0.0791 | g_loss: 7.1151
# Epoch [   34/  100] | d_loss: 0.0565 | g_loss: 7.4168
# Epoch [   34/  100] | d_loss: 0.0108 | g_loss: 5.7694
# Epoch [   35/  100] | d_loss: 0.0824 | g_loss: 7.3702
# Epoch [   35/  100] | d_loss: 0.0265 | g_loss: 5.2143
# Epoch [   35/  100] | d_loss: 0.0455 | g_loss: 8.9349
# Epoch [   35/  100] | d_loss: 0.0660 | g_loss: 4.7141
# Epoch [   35/  100] | d_loss: 0.0759 | g_loss: 5.3494
# Epoch [   35/  100] | d_loss: 0.0420 | g_loss: 6.9079
# Epoch [   36/  100] | d_loss: 0.8826 | g_loss: 8.6857
# Epoch [   36/  100] | d_loss: 0.0681 | g_loss: 6.2708
# Epoch [   36/  100] | d_loss: 0.0172 | g_loss: 6.9160
# Epoch [   36/  100] | d_loss: 0.0446 | g_loss: 10.2362
# Epoch [   36/  100] | d_loss: 0.0178 | g_loss: 7.3483
# Epoch [   36/  100] | d_loss: 0.0521 | g_loss: 7.6969
# Epoch [   37/  100] | d_loss: 0.0387 | g_loss: 9.1649
# Epoch [   37/  100] | d_loss: 0.0019 | g_loss: 7.0871
# Epoch [   37/  100] | d_loss: 0.0167 | g_loss: 7.4895
# Epoch [   37/  100] | d_loss: 0.0720 | g_loss: 6.8854
# Epoch [   37/  100] | d_loss: 0.0165 | g_loss: 11.0851
# Epoch [   37/  100] | d_loss: 0.0190 | g_loss: 5.4589
# Epoch [   38/  100] | d_loss: 0.0380 | g_loss: 10.5090
# Epoch [   38/  100] | d_loss: 0.0793 | g_loss: 7.8595
# Epoch [   38/  100] | d_loss: 0.0067 | g_loss: 7.7038
# Epoch [   38/  100] | d_loss: 0.0163 | g_loss: 9.4819
# Epoch [   38/  100] | d_loss: 0.0078 | g_loss: 6.9232
# Epoch [   38/  100] | d_loss: 0.0182 | g_loss: 13.4361
# Epoch [   39/  100] | d_loss: 0.0010 | g_loss: 11.0404
# Epoch [   39/  100] | d_loss: 0.0437 | g_loss: 5.4615
# Epoch [   39/  100] | d_loss: 0.0209 | g_loss: 8.3186
# Epoch [   39/  100] | d_loss: 0.0311 | g_loss: 8.3981
# Epoch [   39/  100] | d_loss: 0.0248 | g_loss: 10.3654
# Epoch [   39/  100] | d_loss: 0.0049 | g_loss: 9.4650
# Epoch [   40/  100] | d_loss: 0.0014 | g_loss: 8.1261
# Epoch [   40/  100] | d_loss: 0.0333 | g_loss: 8.9169
# Epoch [   40/  100] | d_loss: 0.0344 | g_loss: 9.7846
# Epoch [   40/  100] | d_loss: 0.0118 | g_loss: 7.5287
# Epoch [   40/  100] | d_loss: 0.0075 | g_loss: 8.1384
# Epoch [   40/  100] | d_loss: 0.0109 | g_loss: 7.9051
# Epoch [   41/  100] | d_loss: 0.0045 | g_loss: 9.9576
# Epoch [   41/  100] | d_loss: 0.0208 | g_loss: 6.8083
# Epoch [   41/  100] | d_loss: 0.1169 | g_loss: 8.4536
# Epoch [   41/  100] | d_loss: 0.0518 | g_loss: 7.1969
# Epoch [   41/  100] | d_loss: 0.0226 | g_loss: 7.8033
# Epoch [   41/  100] | d_loss: 0.1304 | g_loss: 8.4005
# Epoch [   42/  100] | d_loss: 0.2798 | g_loss: 6.4218
# Epoch [   42/  100] | d_loss: 0.0962 | g_loss: 7.7321
# Epoch [   42/  100] | d_loss: 0.0146 | g_loss: 8.4153
# Epoch [   42/  100] | d_loss: 0.0167 | g_loss: 8.0651
# Epoch [   42/  100] | d_loss: 0.0104 | g_loss: 4.9774
# Epoch [   42/  100] | d_loss: 0.0068 | g_loss: 8.4987
# Epoch [   43/  100] | d_loss: 0.0118 | g_loss: 12.2486
# Epoch [   43/  100] | d_loss: 0.0113 | g_loss: 7.7865
# Epoch [   43/  100] | d_loss: 0.0123 | g_loss: 7.8491
# Epoch [   43/  100] | d_loss: 0.0083 | g_loss: 8.1408
# Epoch [   43/  100] | d_loss: 0.0295 | g_loss: 6.8658
# Epoch [   43/  100] | d_loss: 0.0105 | g_loss: 7.6318
# Epoch [   44/  100] | d_loss: 0.0109 | g_loss: 7.4041
# Epoch [   44/  100] | d_loss: 0.0110 | g_loss: 7.9950
# Epoch [   44/  100] | d_loss: 0.0123 | g_loss: 8.8385
# Epoch [   44/  100] | d_loss: 0.0071 | g_loss: 8.2057
# Epoch [   44/  100] | d_loss: 0.0100 | g_loss: 9.2250
# Epoch [   44/  100] | d_loss: 0.0183 | g_loss: 7.7875
# Epoch [   45/  100] | d_loss: 0.0100 | g_loss: 7.8394
# Epoch [   45/  100] | d_loss: 0.0335 | g_loss: 8.2391
# Epoch [   45/  100] | d_loss: 0.0070 | g_loss: 9.5733
# Epoch [   45/  100] | d_loss: 0.1139 | g_loss: 7.6116
# Epoch [   45/  100] | d_loss: 0.0066 | g_loss: 6.5087
# Epoch [   45/  100] | d_loss: 0.0143 | g_loss: 7.5630
# Epoch [   46/  100] | d_loss: 0.0250 | g_loss: 8.8544
# Epoch [   46/  100] | d_loss: 0.0025 | g_loss: 7.7123
# Epoch [   46/  100] | d_loss: 0.0084 | g_loss: 6.7588
# Epoch [   46/  100] | d_loss: 0.0040 | g_loss: 6.5194
# Epoch [   46/  100] | d_loss: 0.0315 | g_loss: 8.9486
# Epoch [   46/  100] | d_loss: 0.0201 | g_loss: 6.3115
# Epoch [   47/  100] | d_loss: 0.0050 | g_loss: 7.3848
# Epoch [   47/  100] | d_loss: 0.0366 | g_loss: 9.2089
# Epoch [   47/  100] | d_loss: 0.0175 | g_loss: 8.6064
# Epoch [   47/  100] | d_loss: 0.0098 | g_loss: 10.0442
# Epoch [   47/  100] | d_loss: 0.0127 | g_loss: 9.3114
# Epoch [   47/  100] | d_loss: 0.0121 | g_loss: 7.2483
# Epoch [   48/  100] | d_loss: 0.0123 | g_loss: 7.3604
# Epoch [   48/  100] | d_loss: 0.0072 | g_loss: 9.2866
# Epoch [   48/  100] | d_loss: 0.0026 | g_loss: 6.3670
# Epoch [   48/  100] | d_loss: 0.0060 | g_loss: 7.8517
# Epoch [   48/  100] | d_loss: 0.0008 | g_loss: 7.6269
# Epoch [   48/  100] | d_loss: 0.0131 | g_loss: 5.8873
# Epoch [   49/  100] | d_loss: 0.0365 | g_loss: 6.1938
# Epoch [   49/  100] | d_loss: 0.0957 | g_loss: 6.2586
# Epoch [   49/  100] | d_loss: 0.0679 | g_loss: 6.2012
# Epoch [   49/  100] | d_loss: 0.0339 | g_loss: 9.8444
# Epoch [   49/  100] | d_loss: 0.0248 | g_loss: 6.9252
# Epoch [   49/  100] | d_loss: 0.0290 | g_loss: 9.5875
# Epoch [   50/  100] | d_loss: 0.0495 | g_loss: 5.1426
# Epoch [   50/  100] | d_loss: 0.0049 | g_loss: 7.8573
# Epoch [   50/  100] | d_loss: 0.0166 | g_loss: 7.5541
# Epoch [   50/  100] | d_loss: 0.0056 | g_loss: 10.1114
# Epoch [   50/  100] | d_loss: 0.0269 | g_loss: 9.5270
# Epoch [   50/  100] | d_loss: 0.0075 | g_loss: 9.6739
# Epoch [   51/  100] | d_loss: 0.0140 | g_loss: 7.3360
# Epoch [   51/  100] | d_loss: 0.0241 | g_loss: 7.5014
# Epoch [   51/  100] | d_loss: 0.0175 | g_loss: 7.9774
# Epoch [   51/  100] | d_loss: 0.0077 | g_loss: 8.4655
# Epoch [   51/  100] | d_loss: 0.0091 | g_loss: 7.1967
# Epoch [   51/  100] | d_loss: 0.0084 | g_loss: 9.1966
# Epoch [   52/  100] | d_loss: 0.0017 | g_loss: 8.8353
# Epoch [   52/  100] | d_loss: 1.0544 | g_loss: 10.1005
# Epoch [   52/  100] | d_loss: 0.0317 | g_loss: 6.4536
# Epoch [   52/  100] | d_loss: 0.0018 | g_loss: 7.2385
# Epoch [   52/  100] | d_loss: 0.0080 | g_loss: 6.5940
# Epoch [   52/  100] | d_loss: 0.0082 | g_loss: 6.9822
# Epoch [   53/  100] | d_loss: 0.0102 | g_loss: 8.7860
# Epoch [   53/  100] | d_loss: 0.0184 | g_loss: 9.0095
# Epoch [   53/  100] | d_loss: 0.0157 | g_loss: 6.3949
# Epoch [   53/  100] | d_loss: 0.0336 | g_loss: 6.2907
# Epoch [   53/  100] | d_loss: 0.0539 | g_loss: 7.4448
# Epoch [   53/  100] | d_loss: 0.0355 | g_loss: 9.7361
# Epoch [   54/  100] | d_loss: 0.0023 | g_loss: 8.8954
# Epoch [   54/  100] | d_loss: 0.0033 | g_loss: 7.9777
# Epoch [   54/  100] | d_loss: 0.0692 | g_loss: 8.5799
# Epoch [   54/  100] | d_loss: 0.0104 | g_loss: 6.2480
# Epoch [   54/  100] | d_loss: 0.0398 | g_loss: 7.4492
# Epoch [   54/  100] | d_loss: 0.0040 | g_loss: 8.1883
# Epoch [   55/  100] | d_loss: 0.0286 | g_loss: 8.9980
# Epoch [   55/  100] | d_loss: 0.0825 | g_loss: 6.9629
# Epoch [   55/  100] | d_loss: 0.0155 | g_loss: 9.7650
# Epoch [   55/  100] | d_loss: 0.0092 | g_loss: 9.7960
# Epoch [   55/  100] | d_loss: 0.1095 | g_loss: 5.6999
# Epoch [   55/  100] | d_loss: 0.0044 | g_loss: 7.8826
# Epoch [   56/  100] | d_loss: 0.0134 | g_loss: 8.8101
# Epoch [   56/  100] | d_loss: 0.0109 | g_loss: 8.8644
# Epoch [   56/  100] | d_loss: 0.0116 | g_loss: 8.4792
# Epoch [   56/  100] | d_loss: 0.0058 | g_loss: 8.1605
# Epoch [   56/  100] | d_loss: 0.0034 | g_loss: 4.6199
# Epoch [   56/  100] | d_loss: 0.0305 | g_loss: 10.5219
# Epoch [   57/  100] | d_loss: 0.0429 | g_loss: 6.7099
# Epoch [   57/  100] | d_loss: 0.0019 | g_loss: 11.7447
# Epoch [   57/  100] | d_loss: 0.0015 | g_loss: 8.8917
# Epoch [   57/  100] | d_loss: 0.0313 | g_loss: 7.2773
# Epoch [   57/  100] | d_loss: 0.0225 | g_loss: 7.6582
# Epoch [   57/  100] | d_loss: 0.0633 | g_loss: 11.0328
# Epoch [   58/  100] | d_loss: 0.0328 | g_loss: 5.6725
# Epoch [   58/  100] | d_loss: 0.0277 | g_loss: 8.8175
# Epoch [   58/  100] | d_loss: 0.0103 | g_loss: 8.1069
# Epoch [   58/  100] | d_loss: 0.0106 | g_loss: 8.2284
# Epoch [   58/  100] | d_loss: 0.0185 | g_loss: 9.4579
# Epoch [   58/  100] | d_loss: 0.0050 | g_loss: 8.5792
# Epoch [   59/  100] | d_loss: 0.0185 | g_loss: 6.4723
# Epoch [   59/  100] | d_loss: 0.0130 | g_loss: 7.2133
# Epoch [   59/  100] | d_loss: 0.0076 | g_loss: 9.3364
# Epoch [   59/  100] | d_loss: 0.0045 | g_loss: 9.6871
# Epoch [   59/  100] | d_loss: 0.0140 | g_loss: 8.6614
# Epoch [   59/  100] | d_loss: 0.0018 | g_loss: 9.3090
# Epoch [   60/  100] | d_loss: 0.0236 | g_loss: 7.6075
# Epoch [   60/  100] | d_loss: 0.0202 | g_loss: 7.0578
# Epoch [   60/  100] | d_loss: 0.0147 | g_loss: 9.2934
# Epoch [   60/  100] | d_loss: 0.0332 | g_loss: 9.0953
# Epoch [   60/  100] | d_loss: 0.0909 | g_loss: 7.0313
# Epoch [   60/  100] | d_loss: 0.0076 | g_loss: 8.6479
# Epoch [   61/  100] | d_loss: 0.0127 | g_loss: 9.2113
# Epoch [   61/  100] | d_loss: 0.0050 | g_loss: 8.6054
# Epoch [   61/  100] | d_loss: 3.6187 | g_loss: 1.0020
# Epoch [   61/  100] | d_loss: 0.0688 | g_loss: 5.2951
# Epoch [   61/  100] | d_loss: 0.0395 | g_loss: 8.9118
# Epoch [   61/  100] | d_loss: 0.0068 | g_loss: 6.8063
# Epoch [   62/  100] | d_loss: 0.0127 | g_loss: 9.7128
# Epoch [   62/  100] | d_loss: 0.0061 | g_loss: 8.0045
# Epoch [   62/  100] | d_loss: 0.0012 | g_loss: 7.1401
# Epoch [   62/  100] | d_loss: 0.0251 | g_loss: 8.1177
# Epoch [   62/  100] | d_loss: 0.0311 | g_loss: 8.7463
# Epoch [   62/  100] | d_loss: 0.0169 | g_loss: 7.5148
# Epoch [   63/  100] | d_loss: 0.0212 | g_loss: 8.2642
# Epoch [   63/  100] | d_loss: 0.0310 | g_loss: 10.1707
# Epoch [   63/  100] | d_loss: 0.0016 | g_loss: 9.5329
# Epoch [   63/  100] | d_loss: 0.0218 | g_loss: 9.2136
# Epoch [   63/  100] | d_loss: 0.0021 | g_loss: 7.8085
# Epoch [   63/  100] | d_loss: 0.0015 | g_loss: 8.7856
# Epoch [   64/  100] | d_loss: 0.0042 | g_loss: 8.0863
# Epoch [   64/  100] | d_loss: 0.0256 | g_loss: 5.5094
# Epoch [   64/  100] | d_loss: 0.0011 | g_loss: 8.6255
# Epoch [   64/  100] | d_loss: 0.0099 | g_loss: 9.7719
# Epoch [   64/  100] | d_loss: 0.0049 | g_loss: 7.5146
# Epoch [   64/  100] | d_loss: 0.0160 | g_loss: 7.4870
# Epoch [   65/  100] | d_loss: 0.0064 | g_loss: 7.4210
# Epoch [   65/  100] | d_loss: 0.0069 | g_loss: 10.4536
# Epoch [   65/  100] | d_loss: 0.0021 | g_loss: 8.4014
# Epoch [   65/  100] | d_loss: 0.0336 | g_loss: 4.4376
# Epoch [   65/  100] | d_loss: 0.0084 | g_loss: 9.0073
# Epoch [   65/  100] | d_loss: 0.0105 | g_loss: 9.9538
# Epoch [   66/  100] | d_loss: 0.0058 | g_loss: 10.6449
# Epoch [   66/  100] | d_loss: 0.0063 | g_loss: 9.0954
# Epoch [   66/  100] | d_loss: 0.0133 | g_loss: 8.0275
# Epoch [   66/  100] | d_loss: 0.0055 | g_loss: 10.1073
# Epoch [   66/  100] | d_loss: 0.0085 | g_loss: 8.5079
# Epoch [   66/  100] | d_loss: 0.0334 | g_loss: 7.8592
# Epoch [   67/  100] | d_loss: 0.0154 | g_loss: 8.2058
# Epoch [   67/  100] | d_loss: 0.0050 | g_loss: 8.2050
# Epoch [   67/  100] | d_loss: 0.0110 | g_loss: 10.9066
# Epoch [   67/  100] | d_loss: 0.0081 | g_loss: 8.7168
# Epoch [   67/  100] | d_loss: 0.0118 | g_loss: 9.1904
# Epoch [   67/  100] | d_loss: 0.0111 | g_loss: 9.7759
# Epoch [   68/  100] | d_loss: 0.0034 | g_loss: 8.4782
# Epoch [   68/  100] | d_loss: 0.0067 | g_loss: 9.2737
# Epoch [   68/  100] | d_loss: 0.0022 | g_loss: 7.4387
# Epoch [   68/  100] | d_loss: 0.0090 | g_loss: 11.2379
# Epoch [   68/  100] | d_loss: 0.0065 | g_loss: 8.5757
# Epoch [   68/  100] | d_loss: 0.0055 | g_loss: 10.1841
# Epoch [   69/  100] | d_loss: 0.0258 | g_loss: 9.1540
# Epoch [   69/  100] | d_loss: 0.0008 | g_loss: 8.6515
# Epoch [   69/  100] | d_loss: 0.0100 | g_loss: 11.1724
# Epoch [   69/  100] | d_loss: 0.0005 | g_loss: 6.6957
# Epoch [   69/  100] | d_loss: 0.0306 | g_loss: 10.5502
# Epoch [   69/  100] | d_loss: 0.0045 | g_loss: 11.1718
# Epoch [   70/  100] | d_loss: 0.0028 | g_loss: 10.3290
# Epoch [   70/  100] | d_loss: 0.0044 | g_loss: 9.7381
# Epoch [   70/  100] | d_loss: 0.0042 | g_loss: 7.3781
# Epoch [   70/  100] | d_loss: 0.0050 | g_loss: 8.5380
# Epoch [   70/  100] | d_loss: 0.0086 | g_loss: 11.8428
# Epoch [   70/  100] | d_loss: 0.2400 | g_loss: 3.3786
# Epoch [   71/  100] | d_loss: 0.0067 | g_loss: 7.6696
# Epoch [   71/  100] | d_loss: 0.0364 | g_loss: 11.0322
# Epoch [   71/  100] | d_loss: 0.0376 | g_loss: 10.0165
# Epoch [   71/  100] | d_loss: 0.0172 | g_loss: 5.2445
# Epoch [   71/  100] | d_loss: 0.0063 | g_loss: 9.5733
# Epoch [   71/  100] | d_loss: 0.0015 | g_loss: 9.6541
# Epoch [   72/  100] | d_loss: 0.0147 | g_loss: 7.3427
# Epoch [   72/  100] | d_loss: 0.0034 | g_loss: 6.9002
# Epoch [   72/  100] | d_loss: 0.0046 | g_loss: 9.6441
# Epoch [   72/  100] | d_loss: 0.0023 | g_loss: 8.8816
# Epoch [   72/  100] | d_loss: 0.0031 | g_loss: 11.7659
# Epoch [   72/  100] | d_loss: 0.0021 | g_loss: 10.0592
# Epoch [   73/  100] | d_loss: 0.0391 | g_loss: 9.6772
# Epoch [   73/  100] | d_loss: 0.0158 | g_loss: 8.7801
# Epoch [   73/  100] | d_loss: 0.0087 | g_loss: 8.8742
# Epoch [   73/  100] | d_loss: 0.0010 | g_loss: 7.7470
# Epoch [   73/  100] | d_loss: 0.0031 | g_loss: 9.0806
# Epoch [   73/  100] | d_loss: 0.0050 | g_loss: 7.0105
# Epoch [   74/  100] | d_loss: 0.0016 | g_loss: 10.3337
# Epoch [   74/  100] | d_loss: 0.0010 | g_loss: 9.1931
# Epoch [   74/  100] | d_loss: 0.0044 | g_loss: 8.9883
# Epoch [   74/  100] | d_loss: 0.0005 | g_loss: 8.8420
# Epoch [   74/  100] | d_loss: 0.0046 | g_loss: 9.8135
# Epoch [   74/  100] | d_loss: 0.0018 | g_loss: 10.5087
# Epoch [   75/  100] | d_loss: 0.0024 | g_loss: 6.7506
# Epoch [   75/  100] | d_loss: 0.0030 | g_loss: 8.5883
# Epoch [   75/  100] | d_loss: 0.0202 | g_loss: 10.8884
# Epoch [   75/  100] | d_loss: 0.0009 | g_loss: 9.2219
# Epoch [   75/  100] | d_loss: 0.0211 | g_loss: 8.8983
# Epoch [   75/  100] | d_loss: 0.0020 | g_loss: 8.4794
# Epoch [   76/  100] | d_loss: 0.0618 | g_loss: 9.6504
# Epoch [   76/  100] | d_loss: 0.0009 | g_loss: 10.1496
# Epoch [   76/  100] | d_loss: 0.0046 | g_loss: 9.3471
# Epoch [   76/  100] | d_loss: 0.0134 | g_loss: 9.2646
# Epoch [   76/  100] | d_loss: 0.0035 | g_loss: 8.6960
# Epoch [   76/  100] | d_loss: 0.0108 | g_loss: 9.6938
# Epoch [   77/  100] | d_loss: 0.0047 | g_loss: 6.9655
# Epoch [   77/  100] | d_loss: 0.0022 | g_loss: 11.2005
# Epoch [   77/  100] | d_loss: 0.0049 | g_loss: 6.0501
# Epoch [   77/  100] | d_loss: 0.0037 | g_loss: 10.3273
# Epoch [   77/  100] | d_loss: 0.0811 | g_loss: 14.2052
# Epoch [   77/  100] | d_loss: 0.0043 | g_loss: 10.8063
# Epoch [   78/  100] | d_loss: 0.0144 | g_loss: 6.7118
# Epoch [   78/  100] | d_loss: 0.0012 | g_loss: 7.4574
# Epoch [   78/  100] | d_loss: 0.0269 | g_loss: 8.9005
# Epoch [   78/  100] | d_loss: 0.0080 | g_loss: 8.7261
# Epoch [   78/  100] | d_loss: 0.0115 | g_loss: 9.0648
# Epoch [   78/  100] | d_loss: 0.0029 | g_loss: 8.8956
# Epoch [   79/  100] | d_loss: 0.0063 | g_loss: 7.8668
# Epoch [   79/  100] | d_loss: 0.0007 | g_loss: 9.3118
# Epoch [   79/  100] | d_loss: 0.0079 | g_loss: 9.5904
# Epoch [   79/  100] | d_loss: 0.0062 | g_loss: 9.6178
# Epoch [   79/  100] | d_loss: 0.0030 | g_loss: 10.0243
# Epoch [   79/  100] | d_loss: 0.0013 | g_loss: 8.8114
# Epoch [   80/  100] | d_loss: 0.0045 | g_loss: 9.1940
# Epoch [   80/  100] | d_loss: 0.0036 | g_loss: 8.8782
# Epoch [   80/  100] | d_loss: 0.0038 | g_loss: 9.3813
# Epoch [   80/  100] | d_loss: 0.0015 | g_loss: 10.8067
# Epoch [   80/  100] | d_loss: 0.0017 | g_loss: 9.4927
# Epoch [   80/  100] | d_loss: 0.0035 | g_loss: 9.2653
# Epoch [   81/  100] | d_loss: 0.0180 | g_loss: 10.6819
# Epoch [   81/  100] | d_loss: 0.0076 | g_loss: 10.3023
# Epoch [   81/  100] | d_loss: 0.0119 | g_loss: 9.7660
# Epoch [   81/  100] | d_loss: 0.0307 | g_loss: 6.8736
# Epoch [   81/  100] | d_loss: 0.0116 | g_loss: 8.8241
# Epoch [   81/  100] | d_loss: 0.0028 | g_loss: 6.6995
# Epoch [   82/  100] | d_loss: 0.0061 | g_loss: 10.7267
# Epoch [   82/  100] | d_loss: 0.0074 | g_loss: 8.8442
# Epoch [   82/  100] | d_loss: 0.0018 | g_loss: 9.6564
# Epoch [   82/  100] | d_loss: 0.0234 | g_loss: 11.0580
# Epoch [   82/  100] | d_loss: 0.0034 | g_loss: 8.1270
# Epoch [   82/  100] | d_loss: 0.0018 | g_loss: 7.8673
# Epoch [   83/  100] | d_loss: 0.0078 | g_loss: 12.1849
# Epoch [   83/  100] | d_loss: 0.0225 | g_loss: 7.4824
# Epoch [   83/  100] | d_loss: 0.0367 | g_loss: 9.2104
# Epoch [   83/  100] | d_loss: 0.0034 | g_loss: 7.4907
# Epoch [   83/  100] | d_loss: 0.0017 | g_loss: 9.5192
# Epoch [   83/  100] | d_loss: 0.0100 | g_loss: 8.8043
# Epoch [   84/  100] | d_loss: 0.0025 | g_loss: 10.5963
# Epoch [   84/  100] | d_loss: 0.0006 | g_loss: 8.9144
# Epoch [   84/  100] | d_loss: 0.0011 | g_loss: 10.3879
# Epoch [   84/  100] | d_loss: 0.0298 | g_loss: 10.0072
# Epoch [   84/  100] | d_loss: 0.0118 | g_loss: 10.2037
# Epoch [   84/  100] | d_loss: 0.0035 | g_loss: 9.8915
# Epoch [   85/  100] | d_loss: 0.0015 | g_loss: 11.8724
# Epoch [   85/  100] | d_loss: 0.0095 | g_loss: 10.8983
# Epoch [   85/  100] | d_loss: 0.0009 | g_loss: 8.2134
# Epoch [   85/  100] | d_loss: 0.0004 | g_loss: 8.3724
# Epoch [   85/  100] | d_loss: 0.0012 | g_loss: 10.6081
# Epoch [   85/  100] | d_loss: 0.0005 | g_loss: 8.9229
# Epoch [   86/  100] | d_loss: 0.0015 | g_loss: 11.6737
# Epoch [   86/  100] | d_loss: 0.0023 | g_loss: 10.2633
# Epoch [   86/  100] | d_loss: 0.0030 | g_loss: 7.7550
# Epoch [   86/  100] | d_loss: 0.0089 | g_loss: 8.5662
# Epoch [   86/  100] | d_loss: 0.0014 | g_loss: 8.9087
# Epoch [   86/  100] | d_loss: 0.0302 | g_loss: 8.3318
# Epoch [   87/  100] | d_loss: 0.0020 | g_loss: 9.7158
# Epoch [   87/  100] | d_loss: 0.0051 | g_loss: 9.2306
# Epoch [   87/  100] | d_loss: 0.0739 | g_loss: 9.2649
# Epoch [   87/  100] | d_loss: 0.0015 | g_loss: 10.4773
# Epoch [   87/  100] | d_loss: 0.0024 | g_loss: 11.3649
# Epoch [   87/  100] | d_loss: 0.0282 | g_loss: 5.8550
# Epoch [   88/  100] | d_loss: 0.0123 | g_loss: 10.0492
# Epoch [   88/  100] | d_loss: 0.0027 | g_loss: 6.8108
# Epoch [   88/  100] | d_loss: 0.0355 | g_loss: 7.9691
# Epoch [   88/  100] | d_loss: 0.0039 | g_loss: 10.0259
# Epoch [   88/  100] | d_loss: 0.0057 | g_loss: 8.5838
# Epoch [   88/  100] | d_loss: 0.0030 | g_loss: 10.3746
# Epoch [   89/  100] | d_loss: 0.0022 | g_loss: 9.0436
# Epoch [   89/  100] | d_loss: 0.0026 | g_loss: 10.8725
# Epoch [   89/  100] | d_loss: 0.0008 | g_loss: 11.1811
# Epoch [   89/  100] | d_loss: 0.0037 | g_loss: 10.2084
# Epoch [   89/  100] | d_loss: 0.0038 | g_loss: 10.1752
# Epoch [   89/  100] | d_loss: 0.0052 | g_loss: 8.8204
# Epoch [   90/  100] | d_loss: 0.0010 | g_loss: 9.2284
# Epoch [   90/  100] | d_loss: 0.0029 | g_loss: 7.8718
# Epoch [   90/  100] | d_loss: 0.0013 | g_loss: 9.5645
# Epoch [   90/  100] | d_loss: 0.0006 | g_loss: 9.1285
# Epoch [   90/  100] | d_loss: 0.0007 | g_loss: 8.1516
# Epoch [   90/  100] | d_loss: 0.0075 | g_loss: 8.1233
# Epoch [   91/  100] | d_loss: 0.0013 | g_loss: 7.4142
# Epoch [   91/  100] | d_loss: 0.0078 | g_loss: 11.5954
# Epoch [   91/  100] | d_loss: 0.0029 | g_loss: 11.0484
# Epoch [   91/  100] | d_loss: 0.0031 | g_loss: 11.2661
# Epoch [   91/  100] | d_loss: 0.0074 | g_loss: 9.2397
# Epoch [   91/  100] | d_loss: 0.0163 | g_loss: 10.5244
# Epoch [   92/  100] | d_loss: 0.0069 | g_loss: 9.1582
# Epoch [   92/  100] | d_loss: 0.0042 | g_loss: 11.1281
# Epoch [   92/  100] | d_loss: 0.0009 | g_loss: 6.9382
# Epoch [   92/  100] | d_loss: 0.0100 | g_loss: 12.1505
# Epoch [   92/  100] | d_loss: 0.0003 | g_loss: 8.6332
# Epoch [   92/  100] | d_loss: 0.0012 | g_loss: 9.6822
# Epoch [   93/  100] | d_loss: 0.0028 | g_loss: 9.3732
# Epoch [   93/  100] | d_loss: 0.0042 | g_loss: 8.0939
# Epoch [   93/  100] | d_loss: 0.0012 | g_loss: 11.4974
# Epoch [   93/  100] | d_loss: 0.0103 | g_loss: 10.1822
# Epoch [   93/  100] | d_loss: 0.0054 | g_loss: 7.9371
# Epoch [   93/  100] | d_loss: 0.0031 | g_loss: 9.5149
# Epoch [   94/  100] | d_loss: 0.0035 | g_loss: 8.5238
# Epoch [   94/  100] | d_loss: 0.0009 | g_loss: 10.4600
# Epoch [   94/  100] | d_loss: 0.0001 | g_loss: 9.4964
# Epoch [   94/  100] | d_loss: 0.0011 | g_loss: 9.5545
# Epoch [   94/  100] | d_loss: 0.0113 | g_loss: 9.1896
# Epoch [   94/  100] | d_loss: 0.0087 | g_loss: 9.4952
# Epoch [   95/  100] | d_loss: 0.0028 | g_loss: 9.3433
# Epoch [   95/  100] | d_loss: 0.0026 | g_loss: 9.3925
# Epoch [   95/  100] | d_loss: 0.0092 | g_loss: 9.2903
# Epoch [   95/  100] | d_loss: 0.0093 | g_loss: 9.3329
# Epoch [   95/  100] | d_loss: 0.0026 | g_loss: 9.8233
# Epoch [   95/  100] | d_loss: 0.0039 | g_loss: 9.9465
# Epoch [   96/  100] | d_loss: 0.0098 | g_loss: 8.4936
# Epoch [   96/  100] | d_loss: 0.0002 | g_loss: 11.7322
# Epoch [   96/  100] | d_loss: 0.0016 | g_loss: 12.2909
# Epoch [   96/  100] | d_loss: 0.0024 | g_loss: 7.9951
# Epoch [   96/  100] | d_loss: 0.0068 | g_loss: 10.9202
# Epoch [   96/  100] | d_loss: 0.0140 | g_loss: 11.9067
# Epoch [   97/  100] | d_loss: 0.0009 | g_loss: 9.0690
# Epoch [   97/  100] | d_loss: 0.0074 | g_loss: 9.3362
# Epoch [   97/  100] | d_loss: 0.0057 | g_loss: 10.4707
# Epoch [   97/  100] | d_loss: 0.0036 | g_loss: 6.6070
# Epoch [   97/  100] | d_loss: 0.0104 | g_loss: 8.8357
# Epoch [   97/  100] | d_loss: 0.0023 | g_loss: 7.4522
# Epoch [   98/  100] | d_loss: 0.0010 | g_loss: 10.8599
# Epoch [   98/  100] | d_loss: 0.0029 | g_loss: 8.5204
# Epoch [   98/  100] | d_loss: 0.0091 | g_loss: 8.8078
# Epoch [   98/  100] | d_loss: 0.0011 | g_loss: 9.2456
# Epoch [   98/  100] | d_loss: 0.0005 | g_loss: 10.8572
# Epoch [   98/  100] | d_loss: 0.0008 | g_loss: 9.2304
# Epoch [   99/  100] | d_loss: 0.0096 | g_loss: 10.3257
# Epoch [   99/  100] | d_loss: 0.0992 | g_loss: 7.8812
# Epoch [   99/  100] | d_loss: 0.0142 | g_loss: 9.3938
# Epoch [   99/  100] | d_loss: 0.0023 | g_loss: 7.6999
# Epoch [   99/  100] | d_loss: 0.0028 | g_loss: 10.2196
# Epoch [   99/  100] | d_loss: 0.0153 | g_loss: 9.8339
# Epoch [  100/  100] | d_loss: 0.0051 | g_loss: 9.7025
# Epoch [  100/  100] | d_loss: 0.0016 | g_loss: 8.1828
# Epoch [  100/  100] | d_loss: 0.0096 | g_loss: 10.5187
# Epoch [  100/  100] | d_loss: 0.0006 | g_loss: 11.5736
# Epoch [  100/  100] | d_loss: 0.0099 | g_loss: 10.6366
# Epoch [  100/  100] | d_loss: 0.0021 | g_loss: 10.0546

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
# Take a look at some fake images generated during traning

# helper function for viewing a list of images, for us they are intermediate fake images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img +1)*255 / (2)).astype(np.uint8) # rescale to pixel range (0-255)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
_ = view_samples(-1, samples)
